# %% [markdown]
# # Feature Engineering and Initial ML Model Testing
#
# This script:
# 1. Loads cleaned Yelp review datasets from 'cleaned-data/'.
# 2. Converts text into TF-IDF features with n-grams.
# 3. Trains a basic Logistic Regression model for sentiment prediction.
# 4. Outputs basic accuracy metrics.

# %%
import glob
import os
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
folder = "cleaned-data/"
csv_files = glob.glob(os.path.join(folder, "*.csv"))

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    df['state'] = os.path.splitext(os.path.basename(file))[0]  # optional: keep state info
    dfs.append(df)

data = pd.concat(dfs, ignore_index=True)
data = data.dropna()
print(f"Loaded {len(data)} reviews from {len(dfs)} states.")
# Out:
# Loaded 5222860 reviews from 20 states.

# %%
data = data[data['stars'] != 3]  # remove neutral
data['sentiment'] = data['stars'].apply(lambda x: 0 if x < 3 else (1 if x == 3 else 2))
data.head()
# Out:
#    stars                                               text review_length  \
# 1    4.0  The bun makes the Sonoran Dog. It's like a snu...           114
# 2    5.0  I just started going to Sushi Nara this month ...            95
# 3    4.0  Don't know what it is but If my tummy's feelin...            56
# 4    5.0  We've been coming here since I was a kid. The ...            60
# 5    5.0  Blew $80 on food for the family was worth it f...            31
#
#   num_exclamations num_caps_words  \
# 1                0              2
# 2                1              3
# 3                1              3
# 4                2              3
# 5                2              0
#
#                                           clean_text state  sentiment
# 1  bun makes sonoran dog like snuggie pup first s...    AZ          2
# 2  started going sushi nara month opened short ti...    AZ          2
# 3  dont know tummys feeling icky count chipotles ...    AZ          2
# 4  weve coming since kid staff watched kids grow ...    AZ          2
# 5  blew food family worth food hot orange chicken...    AZ          2

# %%
sample = data.sample(n=100000) # only using 100,000 data points 
X = sample['clean_text']
# y = sample['stars'] # 1-5 RRP
y = sample['sentiment'] # pos/neg/neutral
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# TF-IDF with n-grams
tfidf = TfidfVectorizer(ngram_range=(1,2), max_features=10000)  # unigrams + bigrams
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# Initial ML model: Logistic Regression 
model = LogisticRegression(max_iter=1000)
model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_test_tfidf)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9609
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91      2313
#            2       0.97      0.98      0.97      7687
#
#     accuracy                           0.96     10000
#    macro avg       0.95      0.93      0.94     10000
# weighted avg       0.96      0.96      0.96     10000
