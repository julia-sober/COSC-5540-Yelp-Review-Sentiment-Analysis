# %% [markdown]
# # Feature Engineering and Initial ML Model Testing
#
# This script:
# 1. Loads cleaned Yelp review datasets from 'cleaned-data/'.
# 2. Converts text into TF-IDF features with n-grams.
# 3. Trains a basic Logistic Regression model for sentiment prediction.
# 4. Outputs basic accuracy metrics.

# %%
import glob
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
folder = "cleaned-data/"
csv_files = glob.glob(os.path.join(folder, "*.csv"))

dfs = []
for file in csv_files:
    df = pd.read_csv(file)
    df['state'] = os.path.splitext(os.path.basename(file))[0] 
    dfs.append(df)

data = pd.concat(dfs, ignore_index=True)
data = data.dropna()
print(f"Loaded {len(data)} reviews from {len(dfs)} states.")
# Out:
# Loaded 5222860 reviews from 19 states.

# %%
# creating sentiment score for easier classification
data['sentiment'] = data['stars'].apply(lambda x: 0 if x < 3 else (1 if x == 3 else 2))
data.sample(5)
# Out:
#          stars                                               text  \
# 3126470      5  Innovative and simply delicious.\nFreshly prep...
# 2010101      4  I came to Coopers Hawk at the invitation of a ...
# 1827247      5  MUST SEE!!! If you love tea this is the place ...
# 4155176      5  Fantastic.. The meat loaf sandwich was out of ...
# 4804299      2  The food was good. The service was AWFUL! We w...
#
#          review_length  num_exclamations  num_caps_words  \
# 3126470             46                 0               0
# 2010101            277                 1              10
# 1827247             16                 3               3
# 4155176             21                 0               0
# 4804299             29                 2               1
#
#                                                 clean_text state  sentiment
# 3126470  innovative simply delicious freshly prepared h...    PA          2
# 2010101  came coopers hawk invitation local tampa organ...    FL          2
# 1827247             must see love tea place check tampa fl    FL          2
# 4155176  fantastic meat loaf sandwich world bringing wi...    IN          2
# 4804299  food good service awful around minutes drinks ...    LA          0

# %%
sample = data.sample(n=500000) # only using 500,000 data points for the sake of computation time (instead of 5,000,000) (arbitrary)

X = sample['clean_text']
# y = sample['stars'] # 1-5 RRP
y = sample['sentiment'] # pos/neg/neutral
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# TF-IDF with n-grams
tfidf = TfidfVectorizer(ngram_range=(1,2), max_features=10000)  # unigrams + bigrams
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# Initial ML model: Logistic Regression 
model = LogisticRegression(max_iter=1000)
model.fit(X_train_tfidf, y_train)

y_pred = model.predict(X_test_tfidf)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8773
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     10246
#            1       0.58      0.37      0.45      5653
#            2       0.92      0.97      0.94     34101
#
#     accuracy                           0.88     50000
#    macro avg       0.78      0.73      0.75     50000
# weighted avg       0.86      0.88      0.87     50000

# %%
#Linear Regression model

y = sample['stars']    # 1–5
linreg = LinearRegression()
linreg.fit(X_train_tfidf, y_train)
pred = linreg.predict(X_test_tfidf)

mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)


print("MSE:", mse)
print("R2:", r2)
print("RMSE:",rmse)

# round predictions to nearest whole star
rounded_pred = np.round(pred)

# ensure predictions are between 1 and 5 (since regression might give 0.7 or 5.3)
rounded_pred = np.clip(rounded_pred, 1, 5)

# evaluate accuracy
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, rounded_pred)

print("Accuracy:", accuracy)
# Out:
# MSE: 0.19084159877646376
# R2: 0.7105459029469275
# RMSE: 0.436854207690007
# Accuracy: 0.68222
